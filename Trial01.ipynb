# %%
'Hello' + 'Python' + 'Added'
# Out:
# 'HelloPythonAdded'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)

# %%
# %matplotlib inline
from numpy.random import *

R = randn(10000)
plt.hist(R, bins=100)
plt.show()

# %%
# %matplotlib inline
import requests
url = 'https://datahub.io/core/population/r/population.csv'
response = requests.get(url)

with open('population.csv', 'wb') as csv_file:
  csv_file.write(response.content)
    
import pandas
population = pandas.read_csv('population.csv', index_col=2)

plot = population[population['Country Code']=='JPN'].plot(title='Population in Japan')
plot.set_xlabel("Year")
plot.set_ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=6, releaselevel='final', serial=0)
